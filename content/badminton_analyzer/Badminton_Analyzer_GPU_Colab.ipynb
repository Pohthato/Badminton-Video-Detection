# %% [markdown]
# # Badminton Analyzer - GPU Colab Version
#
# **Updated Instructions (using zip deployment):**
# 1. Create a zip file of your latest `badminton_analyzer` folder from your local machine (include `app.py`, `yolov8n.pt`, `templates/`, `static/`, etc.)
# 2. Upload the zip file when prompted in the cell below
# 3. Change runtime to GPU: Runtime → Change runtime type → GPU
# 4. Run all cells below in order
#
# **Old method (manual upload):**
# - Upload all files individually to Colab if preferred, but the zip method is faster and ensures you have the latest version.

# %%
# Upload your latest badminton_analyzer.zip file
from google.colab import files
uploaded = files.upload()

# Note: This will prompt you to select and upload the zip file from your local machine

# %%
# Extract the deployment package
# !unzip badminton_analyzer.zip

# Move into the extracted directory
# %cd badminton_analyzer

# %%
# Install dependencies
# !pip install flask ultralytics torch torchvision transformers flask-cors python-dotenv pyngrok

# %%
# Check GPU availability
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
else:
    print("No GPU available - using CPU")

# %%
# Create necessary directories
# !mkdir -p templates static uploads

# %%
# Make app accessible from outside Colab
from pyngrok import ngrok
import threading
import time

def run_app():
    # Modify app.py to run on 0.0.0.0:5000 for Colab
    app.run(host='0.0.0.0', port=5000, debug=False)

# Start ngrok tunnel
public_url = ngrok.connect(5000)
print(f"Public URL: {public_url}")

# Start Flask app in background
thread = threading.Thread(target=run_app)
thread.start()

print("App is running! Access it at the public URL above.")
print("Upload your badminton video and test the GPU-accelerated analysis!")
